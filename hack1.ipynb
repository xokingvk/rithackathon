# %% [markdown]
# <a href="https://colab.research.google.com/github/xokingvk/rithackathon/blob/Model_training/hack1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
